# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/KCCAE/KCCAEC2_dataset_latent.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 5. Split Data (Train/Test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

# 6. SMOTE on Train Data Only
smote = SMOTE(random_state=SEED)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)


# 7. One-hot Encoding
y_train_encoded = to_categorical(y_train_smote)
y_test_encoded = to_categorical(y_test)

# 8. Split Train → Train Main & Validation
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train_smote, y_train_encoded, test_size=0.2, random_state=SEED, stratify=y_train_smote
)

# 9. Build DNN + Self-Attention Model
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimension for self-attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention Layer
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Flatten back to 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output Layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model = Model(inputs=input_layer, outputs=output_layer)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 10. Train Model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 11. Evaluate on Test Set
y_pred_prob = model.predict(X_test)
y_pred_class = np.argmax(y_pred_prob, axis=1)
y_true_class = np.argmax(y_test_encoded, axis=1)

# 12. Metrik Evaluasi
print("\n=== Classification Report (Macro) Model DNN FINAL ===")
print(classification_report(y_true_class, y_pred_class, digits=4))
roc_auc = roc_auc_score(y_test_encoded, y_pred_prob, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc:.4f}")

# 12. Simpan Model dalam Format .keras
save_dir = '/content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model'
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, 'dnn+4_techniques..keras')
model.save(model_path)

print(f"Model berhasil disimpan di: {model_path}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.4813 - loss: 1.0010 - val_accuracy: 0.4917 - val_loss: 0.9907
# Epoch 2/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.4879 - loss: 0.9952 - val_accuracy: 0.4919 - val_loss: 0.9896
# Epoch 3/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.4885 - loss: 0.9941 - val_accuracy: 0.4913 - val_loss: 0.9893
# Epoch 4/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.4881 - loss: 0.9934 - val_accuracy: 0.4923 - val_loss: 0.9887
# Epoch 5/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.4892 - loss: 0.9929 - val_accuracy: 0.4924 - val_loss: 0.9882
# Epoch 6/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.4895 - loss: 0.9919 - val_accuracy: 0.4921 - val_loss: 0.9860
# Epoch 7/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4898 - loss: 0.9891 - val_accuracy: 0.4938 - val_loss: 0.9805
# Epoch 8/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4902 - loss: 0.9854 - val_accuracy: 0.4941 - val_loss: 0.9793
# Epoch 9/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - accuracy: 0.4916 - loss: 0.9842 - val_accuracy: 0.4950 - val_loss: 0.9781
# Epoch 10/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.4922 - loss: 0.9835 - val_accuracy: 0.4963 - val_loss: 0.9777
# Epoch 11/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.4931 - loss: 0.9829 - val_accuracy: 0.4960 - val_loss: 0.9770
# Epoch 12/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.4933 - loss: 0.9823 - val_accuracy: 0.4966 - val_loss: 0.9765
# Epoch 13/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.4939 - loss: 0.9818 - val_accuracy: 0.4982 - val_loss: 0.9761
# Epoch 14/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.4946 - loss: 0.9814 - val_accuracy: 0.4989 - val_loss: 0.9760
# Epoch 15/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.4952 - loss: 0.9809 - val_accuracy: 0.4992 - val_loss: 0.9760
# Epoch 16/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4950 - loss: 0.9805 - val_accuracy: 0.4994 - val_loss: 0.9758
# Epoch 17/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.4953 - loss: 0.9801 - val_accuracy: 0.4962 - val_loss: 0.9752
# Epoch 18/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.4960 - loss: 0.9797 - val_accuracy: 0.4975 - val_loss: 0.9750
# Epoch 19/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.4964 - loss: 0.9795 - val_accuracy: 0.4978 - val_loss: 0.9745
# Epoch 20/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 45s 4ms/step - accuracy: 0.4964 - loss: 0.9790 - val_accuracy: 0.5005 - val_loss: 0.9743
# Epoch 21/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4968 - loss: 0.9788 - val_accuracy: 0.5012 - val_loss: 0.9731
# Epoch 22/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4975 - loss: 0.9783 - val_accuracy: 0.5015 - val_loss: 0.9733
# Epoch 23/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.4986 - loss: 0.9779 - val_accuracy: 0.5007 - val_loss: 0.9731
# Epoch 24/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.4986 - loss: 0.9775 - val_accuracy: 0.5038 - val_loss: 0.9722
# Epoch 25/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.4995 - loss: 0.9770 - val_accuracy: 0.5044 - val_loss: 0.9724
# Epoch 26/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.4998 - loss: 0.9765 - val_accuracy: 0.5041 - val_loss: 0.9722
# Epoch 27/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.5004 - loss: 0.9761 - val_accuracy: 0.5034 - val_loss: 0.9719
# Epoch 28/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5009 - loss: 0.9758 - val_accuracy: 0.5034 - val_loss: 0.9710
# Epoch 29/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5015 - loss: 0.9754 - val_accuracy: 0.5043 - val_loss: 0.9708
# Epoch 30/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5020 - loss: 0.9749 - val_accuracy: 0.5048 - val_loss: 0.9710
# Epoch 31/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.5022 - loss: 0.9748 - val_accuracy: 0.5045 - val_loss: 0.9704
# Epoch 32/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - accuracy: 0.5026 - loss: 0.9744 - val_accuracy: 0.5049 - val_loss: 0.9699
# Epoch 33/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - accuracy: 0.5029 - loss: 0.9741 - val_accuracy: 0.5047 - val_loss: 0.9701
# Epoch 34/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.5034 - loss: 0.9739 - val_accuracy: 0.5054 - val_loss: 0.9699
# Epoch 35/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5045 - loss: 0.9737 - val_accuracy: 0.5070 - val_loss: 0.9692
# Epoch 36/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5042 - loss: 0.9733 - val_accuracy: 0.5067 - val_loss: 0.9695
# Epoch 37/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.5040 - loss: 0.9730 - val_accuracy: 0.5063 - val_loss: 0.9687
# Epoch 38/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.5044 - loss: 0.9728 - val_accuracy: 0.5067 - val_loss: 0.9685
# Epoch 39/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5047 - loss: 0.9725 - val_accuracy: 0.5062 - val_loss: 0.9681
# Epoch 40/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5050 - loss: 0.9724 - val_accuracy: 0.5045 - val_loss: 0.9687
# Epoch 41/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5053 - loss: 0.9721 - val_accuracy: 0.5072 - val_loss: 0.9679
# Epoch 42/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5052 - loss: 0.9719 - val_accuracy: 0.5069 - val_loss: 0.9675
# Epoch 43/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5057 - loss: 0.9716 - val_accuracy: 0.5074 - val_loss: 0.9676
# Epoch 44/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5054 - loss: 0.9715 - val_accuracy: 0.5069 - val_loss: 0.9678
# Epoch 45/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5054 - loss: 0.9713 - val_accuracy: 0.5079 - val_loss: 0.9670
# Epoch 46/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5056 - loss: 0.9711 - val_accuracy: 0.5064 - val_loss: 0.9672
# Epoch 47/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5053 - loss: 0.9711 - val_accuracy: 0.5077 - val_loss: 0.9668
# Epoch 48/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5060 - loss: 0.9708 - val_accuracy: 0.5065 - val_loss: 0.9672
# Epoch 49/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5058 - loss: 0.9706 - val_accuracy: 0.5092 - val_loss: 0.9667
# Epoch 50/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5059 - loss: 0.9704 - val_accuracy: 0.5085 - val_loss: 0.9671
# Epoch 51/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5057 - loss: 0.9703 - val_accuracy: 0.5066 - val_loss: 0.9670
# Epoch 52/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - accuracy: 0.5064 - loss: 0.9700 - val_accuracy: 0.5075 - val_loss: 0.9664
# Epoch 53/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5066 - loss: 0.9699 - val_accuracy: 0.5080 - val_loss: 0.9659
# Epoch 54/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5068 - loss: 0.9698 - val_accuracy: 0.5068 - val_loss: 0.9663
# Epoch 55/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5064 - loss: 0.9696 - val_accuracy: 0.5090 - val_loss: 0.9657
# Epoch 56/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.5066 - loss: 0.9694 - val_accuracy: 0.5079 - val_loss: 0.9659
# Epoch 57/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5068 - loss: 0.9692 - val_accuracy: 0.5091 - val_loss: 0.9654
# Epoch 58/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5067 - loss: 0.9690 - val_accuracy: 0.5094 - val_loss: 0.9651
# Epoch 59/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5060 - loss: 0.9689 - val_accuracy: 0.5083 - val_loss: 0.9662
# Epoch 60/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5064 - loss: 0.9689 - val_accuracy: 0.5088 - val_loss: 0.9653
# Epoch 61/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5066 - loss: 0.9686 - val_accuracy: 0.5073 - val_loss: 0.9655
# Epoch 62/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5066 - loss: 0.9686 - val_accuracy: 0.5083 - val_loss: 0.9658
# Epoch 63/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5073 - loss: 0.9684 - val_accuracy: 0.5079 - val_loss: 0.9651
# Epoch 64/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5069 - loss: 0.9684 - val_accuracy: 0.5102 - val_loss: 0.9654
# Epoch 65/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5074 - loss: 0.9682 - val_accuracy: 0.5097 - val_loss: 0.9647
# Epoch 66/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.5074 - loss: 0.9679 - val_accuracy: 0.5089 - val_loss: 0.9653
# Epoch 67/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - accuracy: 0.5076 - loss: 0.9679 - val_accuracy: 0.5085 - val_loss: 0.9650
# Epoch 68/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5077 - loss: 0.9679 - val_accuracy: 0.5074 - val_loss: 0.9657
# Epoch 69/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5078 - loss: 0.9678 - val_accuracy: 0.5070 - val_loss: 0.9655
# Epoch 70/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5071 - loss: 0.9678 - val_accuracy: 0.5096 - val_loss: 0.9641
# Epoch 71/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5075 - loss: 0.9675 - val_accuracy: 0.5071 - val_loss: 0.9654
# Epoch 72/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5075 - loss: 0.9674 - val_accuracy: 0.5072 - val_loss: 0.9648
# Epoch 73/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5075 - loss: 0.9673 - val_accuracy: 0.5068 - val_loss: 0.9660
# Epoch 74/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.5076 - loss: 0.9672 - val_accuracy: 0.5080 - val_loss: 0.9642
# Epoch 75/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.5082 - loss: 0.9670 - val_accuracy: 0.5086 - val_loss: 0.9641
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# === Classification Report (Macro) Model DNN FINAL ===
#               precision    recall  f1-score   support
#
#            0     0.9416    0.6267    0.7525     42741
#            1     0.0266    0.3531    0.0495       926
#            2     0.3369    0.4770    0.3949      7069
#
#     accuracy                         0.6009     50736
#    macro avg     0.4350    0.4856    0.3990     50736
# weighted avg     0.8406    0.6009    0.6899     50736
#
#
# Macro-average ROC AUC: 0.7412
# Model berhasil disimpan di: /content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model/dnn+4_techniques..keras
