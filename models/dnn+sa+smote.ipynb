# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/diabetes_012_health_indicators_BRFSS2015.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 4. Preprocessing
X['BMI'] = winsorize(X['BMI'], limits=[0.005, 0.005])
X['MentHlth'] = np.where(X['MentHlth'] > 30, 30, X['MentHlth'])
X['PhysHlth'] = np.where(X['PhysHlth'] > 30, 30, X['PhysHlth'])

robust_features = ['BMI', 'MentHlth', 'PhysHlth']
minmax_features = ['Age', 'Education', 'Income', 'GenHlth']

scaler_robust = RobustScaler()
scaler_minmax = MinMaxScaler()

X[robust_features] = scaler_robust.fit_transform(X[robust_features])
X[minmax_features] = scaler_minmax.fit_transform(X[minmax_features])

# 5. Split Data (Train/Test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

# 6. SMOTE on Train Data Only
smote = SMOTE(random_state=SEED)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Simpan hasil SMOTE jika dibutuhkan
# df_train_smote = pd.DataFrame(X_train_smote, columns=X_train.columns)
# df_train_smote['Diabetes_012'] = y_train_smote
# df_train_smote.to_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/Output DNN+SMOTE.csv', index=False)

# 7. One-hot Encoding
y_train_encoded = to_categorical(y_train_smote)
y_test_encoded = to_categorical(y_test)

# 8. Split Train → Train Main & Validation
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train_smote, y_train_encoded, test_size=0.2, random_state=SEED, stratify=y_train_smote
)

# 9. Build DNN + Self-Attention Model
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimension for self-attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention Layer
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Flatten back to 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output Layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model = Model(inputs=input_layer, outputs=output_layer)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 10. Train Model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 11. Evaluate on Test Set
y_pred_prob = model.predict(X_test)
y_pred_class = np.argmax(y_pred_prob, axis=1)
y_true_class = np.argmax(y_test_encoded, axis=1)

# 12. Metrik Evaluasi
print("\n=== Classification Report (Macro) Model DNN + SMOTE + SA ===")
print(classification_report(y_true_class, y_pred_class, digits=4))
roc_auc = roc_auc_score(y_test_encoded, y_pred_prob, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc:.4f}")


# # 12. Simpan Model dalam Format .keras
# save_dir = '/content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model'
# os.makedirs(save_dir, exist_ok=True)

# model_path = os.path.join(save_dir, 'dnn+sa+smote.keras')
# model.save(model_path)

# print(f"Model berhasil disimpan di: {model_path}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5273 - loss: 0.9410 - val_accuracy: 0.5789 - val_loss: 0.8798
# Epoch 2/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - accuracy: 0.5867 - loss: 0.8732 - val_accuracy: 0.6058 - val_loss: 0.8450
# Epoch 3/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.6172 - loss: 0.8284 - val_accuracy: 0.6226 - val_loss: 0.8198
# Epoch 4/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.6347 - loss: 0.8022 - val_accuracy: 0.6320 - val_loss: 0.8025
# Epoch 5/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6432 - loss: 0.7859 - val_accuracy: 0.6417 - val_loss: 0.7884
# Epoch 6/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.6508 - loss: 0.7729 - val_accuracy: 0.6456 - val_loss: 0.7819
# Epoch 7/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.6565 - loss: 0.7621 - val_accuracy: 0.6570 - val_loss: 0.7633
# Epoch 8/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.6622 - loss: 0.7526 - val_accuracy: 0.6599 - val_loss: 0.7566
# Epoch 9/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6669 - loss: 0.7451 - val_accuracy: 0.6650 - val_loss: 0.7478
# Epoch 10/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.6704 - loss: 0.7391 - val_accuracy: 0.6697 - val_loss: 0.7400
# Epoch 11/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.6727 - loss: 0.7340 - val_accuracy: 0.6721 - val_loss: 0.7352
# Epoch 12/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.6754 - loss: 0.7295 - val_accuracy: 0.6733 - val_loss: 0.7327
# Epoch 13/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.6780 - loss: 0.7248 - val_accuracy: 0.6773 - val_loss: 0.7256
# Epoch 14/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.6798 - loss: 0.7210 - val_accuracy: 0.6773 - val_loss: 0.7254
# Epoch 15/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.6817 - loss: 0.7173 - val_accuracy: 0.6807 - val_loss: 0.7204
# Epoch 16/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.6835 - loss: 0.7141 - val_accuracy: 0.6809 - val_loss: 0.7192
# Epoch 17/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6846 - loss: 0.7111 - val_accuracy: 0.6829 - val_loss: 0.7147
# Epoch 18/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.6866 - loss: 0.7082 - val_accuracy: 0.6807 - val_loss: 0.7181
# Epoch 19/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.6883 - loss: 0.7055 - val_accuracy: 0.6831 - val_loss: 0.7133
# Epoch 20/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.6891 - loss: 0.7032 - val_accuracy: 0.6847 - val_loss: 0.7101
# Epoch 21/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.6899 - loss: 0.7010 - val_accuracy: 0.6860 - val_loss: 0.7064
# Epoch 22/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.6911 - loss: 0.6989 - val_accuracy: 0.6883 - val_loss: 0.7039
# Epoch 23/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.6920 - loss: 0.6966 - val_accuracy: 0.6905 - val_loss: 0.7010
# Epoch 24/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.6932 - loss: 0.6949 - val_accuracy: 0.6911 - val_loss: 0.6985
# Epoch 25/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.6946 - loss: 0.6933 - val_accuracy: 0.6915 - val_loss: 0.6985
# Epoch 26/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6949 - loss: 0.6917 - val_accuracy: 0.6928 - val_loss: 0.6963
# Epoch 27/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6957 - loss: 0.6902 - val_accuracy: 0.6926 - val_loss: 0.6962
# Epoch 28/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.6961 - loss: 0.6887 - val_accuracy: 0.6940 - val_loss: 0.6950
# Epoch 29/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6976 - loss: 0.6873 - val_accuracy: 0.6949 - val_loss: 0.6940
# Epoch 30/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.6980 - loss: 0.6860 - val_accuracy: 0.6956 - val_loss: 0.6903
# Epoch 31/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.6989 - loss: 0.6843 - val_accuracy: 0.6933 - val_loss: 0.6938
# Epoch 32/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.6996 - loss: 0.6835 - val_accuracy: 0.6959 - val_loss: 0.6889
# Epoch 33/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.7000 - loss: 0.6823 - val_accuracy: 0.6959 - val_loss: 0.6897
# Epoch 34/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.7002 - loss: 0.6810 - val_accuracy: 0.6962 - val_loss: 0.6879
# Epoch 35/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.7010 - loss: 0.6797 - val_accuracy: 0.6961 - val_loss: 0.6888
# Epoch 36/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.7021 - loss: 0.6787 - val_accuracy: 0.6972 - val_loss: 0.6882
# Epoch 37/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.7023 - loss: 0.6776 - val_accuracy: 0.6976 - val_loss: 0.6856
# Epoch 38/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.7026 - loss: 0.6770 - val_accuracy: 0.6977 - val_loss: 0.6848
# Epoch 39/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.7028 - loss: 0.6761 - val_accuracy: 0.6974 - val_loss: 0.6852
# Epoch 40/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.7033 - loss: 0.6751 - val_accuracy: 0.6982 - val_loss: 0.6847
# Epoch 41/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.7042 - loss: 0.6742 - val_accuracy: 0.6978 - val_loss: 0.6853
# Epoch 42/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.7045 - loss: 0.6737 - val_accuracy: 0.6988 - val_loss: 0.6835
# Epoch 43/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.7043 - loss: 0.6732 - val_accuracy: 0.7004 - val_loss: 0.6814
# Epoch 44/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.7051 - loss: 0.6723 - val_accuracy: 0.7008 - val_loss: 0.6802
# Epoch 45/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.7055 - loss: 0.6717 - val_accuracy: 0.7002 - val_loss: 0.6805
# Epoch 46/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 47s 5ms/step - accuracy: 0.7062 - loss: 0.6708 - val_accuracy: 0.7009 - val_loss: 0.6804
# Epoch 47/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - accuracy: 0.7067 - loss: 0.6701 - val_accuracy: 0.7005 - val_loss: 0.6814
# Epoch 48/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.7068 - loss: 0.6696 - val_accuracy: 0.7010 - val_loss: 0.6801
# Epoch 49/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.7068 - loss: 0.6690 - val_accuracy: 0.7016 - val_loss: 0.6791
# Epoch 50/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.7074 - loss: 0.6683 - val_accuracy: 0.7023 - val_loss: 0.6774
# Epoch 51/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.7077 - loss: 0.6676 - val_accuracy: 0.7007 - val_loss: 0.6786
# Epoch 52/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - accuracy: 0.7080 - loss: 0.6670 - val_accuracy: 0.7003 - val_loss: 0.6781
# Epoch 53/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.7081 - loss: 0.6664 - val_accuracy: 0.7021 - val_loss: 0.6750
# Epoch 54/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 38s 5ms/step - accuracy: 0.7080 - loss: 0.6661 - val_accuracy: 0.7028 - val_loss: 0.6731
# Epoch 55/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.7090 - loss: 0.6655 - val_accuracy: 0.7025 - val_loss: 0.6742
# Epoch 56/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.7089 - loss: 0.6651 - val_accuracy: 0.7036 - val_loss: 0.6720
# Epoch 57/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 47s 5ms/step - accuracy: 0.7093 - loss: 0.6646 - val_accuracy: 0.7029 - val_loss: 0.6732
# Epoch 58/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 38s 5ms/step - accuracy: 0.7094 - loss: 0.6642 - val_accuracy: 0.7025 - val_loss: 0.6745
# Epoch 59/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - accuracy: 0.7096 - loss: 0.6639 - val_accuracy: 0.7035 - val_loss: 0.6721
# Epoch 60/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.7103 - loss: 0.6634 - val_accuracy: 0.7023 - val_loss: 0.6740
# Epoch 61/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.7101 - loss: 0.6633 - val_accuracy: 0.7013 - val_loss: 0.6758
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# === Classification Report (Macro) Model DNN + SMOTE + SA ===
#               precision    recall  f1-score   support
#
#            0     0.9367    0.6736    0.7837     42741
#            1     0.0281    0.2235    0.0500       926
#            2     0.3316    0.5930    0.4253      7069
#
#     accuracy                         0.6542     50736
#    macro avg     0.4321    0.4967    0.4197     50736
# weighted avg     0.8358    0.6542    0.7204     50736
#
#
# Macro-average ROC AUC: 0.7211
