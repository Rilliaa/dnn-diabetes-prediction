# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/AE/AEB1_dataset_latent.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 5. Split Data (Train/Test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

# 6. SMOTE on Train Data Only
smote = SMOTE(random_state=SEED)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)


# 7. One-hot Encoding
y_train_encoded = to_categorical(y_train_smote)
y_test_encoded = to_categorical(y_test)

# 8. Split Train → Train Main & Validation
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train_smote, y_train_encoded, test_size=0.2, random_state=SEED, stratify=y_train_smote
)

# 9. Build DNN + Self-Attention Model
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimension for self-attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention Layer
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Flatten back to 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output Layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model = Model(inputs=input_layer, outputs=output_layer)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 10. Train Model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 11. Evaluate on Test Set
y_pred_prob = model.predict(X_test)
y_pred_class = np.argmax(y_pred_prob, axis=1)
y_true_class = np.argmax(y_test_encoded, axis=1)

# 12. Metrik Evaluasi
print("\n=== Classification Report (Macro) Model DNN + AE + SMOTE + SA ===")
print(classification_report(y_true_class, y_pred_class, digits=4))
roc_auc = roc_auc_score(y_test_encoded, y_pred_prob, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc:.4f}")


# 13. Simpan Model dalam Format .keras
save_dir = '/content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model'
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, 'dnn+ae+sa+smote.keras')
model.save(model_path)

print(f"Model berhasil disimpan di: {model_path}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.4903 - loss: 0.9881 - val_accuracy: 0.5148 - val_loss: 0.9615
# Epoch 2/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - accuracy: 0.5101 - loss: 0.9644 - val_accuracy: 0.5240 - val_loss: 0.9482
# Epoch 3/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5209 - loss: 0.9485 - val_accuracy: 0.5248 - val_loss: 0.9462
# Epoch 4/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5271 - loss: 0.9397 - val_accuracy: 0.5328 - val_loss: 0.9378
# Epoch 5/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.5321 - loss: 0.9346 - val_accuracy: 0.5416 - val_loss: 0.9268
# Epoch 6/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5358 - loss: 0.9304 - val_accuracy: 0.5397 - val_loss: 0.9293
# Epoch 7/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5384 - loss: 0.9271 - val_accuracy: 0.5431 - val_loss: 0.9218
# Epoch 8/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5408 - loss: 0.9232 - val_accuracy: 0.5454 - val_loss: 0.9217
# Epoch 9/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5440 - loss: 0.9201 - val_accuracy: 0.5466 - val_loss: 0.9179
# Epoch 10/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5457 - loss: 0.9178 - val_accuracy: 0.5483 - val_loss: 0.9144
# Epoch 11/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5477 - loss: 0.9143 - val_accuracy: 0.5515 - val_loss: 0.9106
# Epoch 12/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5508 - loss: 0.9110 - val_accuracy: 0.5555 - val_loss: 0.9055
# Epoch 13/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5529 - loss: 0.9078 - val_accuracy: 0.5574 - val_loss: 0.9002
# Epoch 14/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5546 - loss: 0.9053 - val_accuracy: 0.5592 - val_loss: 0.9019
# Epoch 15/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5574 - loss: 0.9025 - val_accuracy: 0.5595 - val_loss: 0.8999
# Epoch 16/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5594 - loss: 0.9000 - val_accuracy: 0.5622 - val_loss: 0.8966
# Epoch 17/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5601 - loss: 0.8982 - val_accuracy: 0.5642 - val_loss: 0.8952
# Epoch 18/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5622 - loss: 0.8957 - val_accuracy: 0.5617 - val_loss: 0.8944
# Epoch 19/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5637 - loss: 0.8943 - val_accuracy: 0.5658 - val_loss: 0.8935
# Epoch 20/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5652 - loss: 0.8924 - val_accuracy: 0.5646 - val_loss: 0.8955
# Epoch 21/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5671 - loss: 0.8901 - val_accuracy: 0.5652 - val_loss: 0.8898
# Epoch 22/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5684 - loss: 0.8887 - val_accuracy: 0.5669 - val_loss: 0.8895
# Epoch 23/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5697 - loss: 0.8869 - val_accuracy: 0.5664 - val_loss: 0.8878
# Epoch 24/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5711 - loss: 0.8854 - val_accuracy: 0.5730 - val_loss: 0.8829
# Epoch 25/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5731 - loss: 0.8834 - val_accuracy: 0.5706 - val_loss: 0.8850
# Epoch 26/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5741 - loss: 0.8820 - val_accuracy: 0.5739 - val_loss: 0.8802
# Epoch 27/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5748 - loss: 0.8802 - val_accuracy: 0.5786 - val_loss: 0.8738
# Epoch 28/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5758 - loss: 0.8786 - val_accuracy: 0.5796 - val_loss: 0.8716
# Epoch 29/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5779 - loss: 0.8772 - val_accuracy: 0.5798 - val_loss: 0.8715
# Epoch 30/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5787 - loss: 0.8758 - val_accuracy: 0.5811 - val_loss: 0.8707
# Epoch 31/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5799 - loss: 0.8745 - val_accuracy: 0.5805 - val_loss: 0.8702
# Epoch 32/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.5813 - loss: 0.8729 - val_accuracy: 0.5855 - val_loss: 0.8664
# Epoch 33/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5829 - loss: 0.8712 - val_accuracy: 0.5862 - val_loss: 0.8646
# Epoch 34/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5840 - loss: 0.8699 - val_accuracy: 0.5886 - val_loss: 0.8632
# Epoch 35/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5854 - loss: 0.8686 - val_accuracy: 0.5893 - val_loss: 0.8618
# Epoch 36/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5863 - loss: 0.8669 - val_accuracy: 0.5910 - val_loss: 0.8613
# Epoch 37/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5873 - loss: 0.8657 - val_accuracy: 0.5914 - val_loss: 0.8614
# Epoch 38/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5891 - loss: 0.8640 - val_accuracy: 0.5906 - val_loss: 0.8601
# Epoch 39/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5883 - loss: 0.8633 - val_accuracy: 0.5921 - val_loss: 0.8593
# Epoch 40/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5899 - loss: 0.8619 - val_accuracy: 0.5943 - val_loss: 0.8565
# Epoch 41/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5905 - loss: 0.8607 - val_accuracy: 0.5913 - val_loss: 0.8592
# Epoch 42/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5903 - loss: 0.8595 - val_accuracy: 0.5918 - val_loss: 0.8588
# Epoch 43/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5912 - loss: 0.8585 - val_accuracy: 0.5944 - val_loss: 0.8570
# Epoch 44/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5924 - loss: 0.8571 - val_accuracy: 0.5935 - val_loss: 0.8570
# Epoch 45/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5925 - loss: 0.8560 - val_accuracy: 0.5938 - val_loss: 0.8563
# Epoch 46/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5932 - loss: 0.8550 - val_accuracy: 0.5926 - val_loss: 0.8553
# Epoch 47/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.5938 - loss: 0.8538 - val_accuracy: 0.5946 - val_loss: 0.8547
# Epoch 48/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.5946 - loss: 0.8527 - val_accuracy: 0.5930 - val_loss: 0.8593
# Epoch 49/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5945 - loss: 0.8520 - val_accuracy: 0.5933 - val_loss: 0.8572
# Epoch 50/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5947 - loss: 0.8513 - val_accuracy: 0.5956 - val_loss: 0.8538
# Epoch 51/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5958 - loss: 0.8502 - val_accuracy: 0.5934 - val_loss: 0.8567
# Epoch 52/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - accuracy: 0.5962 - loss: 0.8496 - val_accuracy: 0.5930 - val_loss: 0.8575
# Epoch 53/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.5965 - loss: 0.8489 - val_accuracy: 0.5958 - val_loss: 0.8540
# Epoch 54/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5970 - loss: 0.8480 - val_accuracy: 0.5960 - val_loss: 0.8529
# Epoch 55/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5979 - loss: 0.8470 - val_accuracy: 0.5957 - val_loss: 0.8529
# Epoch 56/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.5978 - loss: 0.8461 - val_accuracy: 0.5947 - val_loss: 0.8546
# Epoch 57/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5979 - loss: 0.8454 - val_accuracy: 0.5950 - val_loss: 0.8532
# Epoch 58/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.5987 - loss: 0.8445 - val_accuracy: 0.5964 - val_loss: 0.8503
# Epoch 59/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5995 - loss: 0.8435 - val_accuracy: 0.5954 - val_loss: 0.8510
# Epoch 60/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5993 - loss: 0.8427 - val_accuracy: 0.5996 - val_loss: 0.8448
# Epoch 61/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - accuracy: 0.6002 - loss: 0.8419 - val_accuracy: 0.5946 - val_loss: 0.8524
# Epoch 62/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.6002 - loss: 0.8415 - val_accuracy: 0.6008 - val_loss: 0.8412
# Epoch 63/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.6005 - loss: 0.8405 - val_accuracy: 0.5992 - val_loss: 0.8434
# Epoch 64/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 38s 5ms/step - accuracy: 0.6007 - loss: 0.8402 - val_accuracy: 0.5960 - val_loss: 0.8479
# Epoch 65/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.6009 - loss: 0.8396 - val_accuracy: 0.6015 - val_loss: 0.8406
# Epoch 66/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.6019 - loss: 0.8390 - val_accuracy: 0.5991 - val_loss: 0.8429
# Epoch 67/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.6020 - loss: 0.8380 - val_accuracy: 0.6003 - val_loss: 0.8396
# Epoch 68/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.6021 - loss: 0.8376 - val_accuracy: 0.5997 - val_loss: 0.8399
# Epoch 69/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - accuracy: 0.6020 - loss: 0.8368 - val_accuracy: 0.6021 - val_loss: 0.8370
# Epoch 70/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.6029 - loss: 0.8362 - val_accuracy: 0.6008 - val_loss: 0.8397
# Epoch 71/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.6036 - loss: 0.8359 - val_accuracy: 0.6014 - val_loss: 0.8375
# Epoch 72/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - accuracy: 0.6031 - loss: 0.8352 - val_accuracy: 0.6027 - val_loss: 0.8384
# Epoch 73/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.6034 - loss: 0.8349 - val_accuracy: 0.6011 - val_loss: 0.8381
# Epoch 74/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.6041 - loss: 0.8347 - val_accuracy: 0.6000 - val_loss: 0.8402
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#
# === Classification Report (Macro) Model DNN + AE + SMOTE + SA ===
#               precision    recall  f1-score   support
#
#            0     0.9402    0.6607    0.7760     42741
#            1     0.0265    0.2311    0.0476       926
#            2     0.3206    0.5729    0.4111      7069
#
#     accuracy                         0.6406     50736
#    macro avg     0.4291    0.4882    0.4116     50736
# weighted avg     0.8372    0.6406    0.7119     50736
#
#
# Macro-average ROC AUC: 0.7275
# Model berhasil disimpan di: /content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model/dnn+ae+sa+smote.keras
