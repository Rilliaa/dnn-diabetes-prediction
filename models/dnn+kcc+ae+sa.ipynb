# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Dropout, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/KCCAE/KCCAEC2_dataset_latent.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 5. One-hot Encoding untuk Target
y_encoded = to_categorical(y)

# 6. Split Data (Train/Test -> Train/Val)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=SEED, stratify=y
)
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=SEED, stratify=y_train.argmax(axis=1)
)

# 7. Build DNN + Self-Attention Layer (Moved before Output Layer)
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimensi untuk Self-Attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention sebelum output
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Kembalikan ke bentuk 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model_sa = Model(inputs=input_layer, outputs=output_layer)
model_sa.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Train Model (Updated Epochs: 100)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_sa = model_sa.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 9. Evaluate
y_pred_prob_sa = model_sa.predict(X_test)
y_pred_class_sa = np.argmax(y_pred_prob_sa, axis=1)
y_true_class_sa = np.argmax(y_test, axis=1)

print("\n=== Classification Report (Macro) DNN + KCC + AE + SA ===")
print(classification_report(y_true_class_sa, y_pred_class_sa, digits=4))
roc_auc_sa = roc_auc_score(y_test, y_pred_prob_sa, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc_sa:.4f}")


# 12. Simpan Model dalam Format .keras
save_dir = '/content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model'
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, 'dnn+kcc+ae+sa.keras')
model_sa.save(model_path)

print(f"Model berhasil disimpan di: {model_path}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8415 - loss: 0.4335 - val_accuracy: 0.8454 - val_loss: 0.4199
# Epoch 2/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8467 - loss: 0.4185 - val_accuracy: 0.8456 - val_loss: 0.4201
# Epoch 3/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.8467 - loss: 0.4179 - val_accuracy: 0.8459 - val_loss: 0.4198
# Epoch 4/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8471 - loss: 0.4175 - val_accuracy: 0.8460 - val_loss: 0.4197
# Epoch 5/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8474 - loss: 0.4172 - val_accuracy: 0.8460 - val_loss: 0.4195
# Epoch 6/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8471 - loss: 0.4170 - val_accuracy: 0.8460 - val_loss: 0.4195
# Epoch 7/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8473 - loss: 0.4169 - val_accuracy: 0.8464 - val_loss: 0.4193
# Epoch 8/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.8474 - loss: 0.4167 - val_accuracy: 0.8462 - val_loss: 0.4192
# Epoch 9/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.8476 - loss: 0.4166 - val_accuracy: 0.8463 - val_loss: 0.4192
# Epoch 10/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8476 - loss: 0.4165 - val_accuracy: 0.8464 - val_loss: 0.4191
# Epoch 11/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8475 - loss: 0.4166 - val_accuracy: 0.8467 - val_loss: 0.4189
# Epoch 12/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8474 - loss: 0.4165 - val_accuracy: 0.8469 - val_loss: 0.4188
# Epoch 13/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.8475 - loss: 0.4164 - val_accuracy: 0.8469 - val_loss: 0.4188
# Epoch 14/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8476 - loss: 0.4163 - val_accuracy: 0.8473 - val_loss: 0.4186
# Epoch 15/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.8475 - loss: 0.4163 - val_accuracy: 0.8469 - val_loss: 0.4187
# Epoch 16/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8475 - loss: 0.4162 - val_accuracy: 0.8470 - val_loss: 0.4185
# Epoch 17/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8477 - loss: 0.4162 - val_accuracy: 0.8472 - val_loss: 0.4185
# Epoch 18/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8478 - loss: 0.4161 - val_accuracy: 0.8474 - val_loss: 0.4185
# Epoch 19/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8476 - loss: 0.4161 - val_accuracy: 0.8473 - val_loss: 0.4185
# Epoch 20/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8477 - loss: 0.4161 - val_accuracy: 0.8470 - val_loss: 0.4184
# Epoch 21/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.8477 - loss: 0.4160 - val_accuracy: 0.8474 - val_loss: 0.4184
# Epoch 22/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8477 - loss: 0.4161 - val_accuracy: 0.8472 - val_loss: 0.4184
# Epoch 23/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8476 - loss: 0.4160 - val_accuracy: 0.8472 - val_loss: 0.4183
# Epoch 24/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - accuracy: 0.8478 - loss: 0.4160 - val_accuracy: 0.8472 - val_loss: 0.4184
# Epoch 25/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.8476 - loss: 0.4160 - val_accuracy: 0.8473 - val_loss: 0.4183
# Epoch 26/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.8474 - loss: 0.4160 - val_accuracy: 0.8471 - val_loss: 0.4183
# Epoch 27/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8478 - loss: 0.4160 - val_accuracy: 0.8472 - val_loss: 0.4182
# Epoch 28/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.8477 - loss: 0.4159 - val_accuracy: 0.8473 - val_loss: 0.4183
# Epoch 29/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8478 - loss: 0.4159 - val_accuracy: 0.8473 - val_loss: 0.4182
# Epoch 30/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8477 - loss: 0.4159 - val_accuracy: 0.8474 - val_loss: 0.4182
# Epoch 31/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8476 - loss: 0.4159 - val_accuracy: 0.8474 - val_loss: 0.4183
# Epoch 32/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8476 - loss: 0.4159 - val_accuracy: 0.8474 - val_loss: 0.4182
# Epoch 33/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8478 - loss: 0.4159 - val_accuracy: 0.8471 - val_loss: 0.4181
# Epoch 34/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8476 - loss: 0.4158 - val_accuracy: 0.8471 - val_loss: 0.4182
# Epoch 35/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8477 - loss: 0.4159 - val_accuracy: 0.8474 - val_loss: 0.4182
# Epoch 36/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8479 - loss: 0.4158 - val_accuracy: 0.8476 - val_loss: 0.4181
# Epoch 37/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.8479 - loss: 0.4158 - val_accuracy: 0.8471 - val_loss: 0.4182
# Epoch 38/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8480 - loss: 0.4158 - val_accuracy: 0.8472 - val_loss: 0.4182
# Epoch 39/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8477 - loss: 0.4158 - val_accuracy: 0.8470 - val_loss: 0.4182
# Epoch 40/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8479 - loss: 0.4158 - val_accuracy: 0.8469 - val_loss: 0.4181
# Epoch 41/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8478 - loss: 0.4158 - val_accuracy: 0.8475 - val_loss: 0.4180
# Epoch 42/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8479 - loss: 0.4158 - val_accuracy: 0.8469 - val_loss: 0.4181
# Epoch 43/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.8477 - loss: 0.4158 - val_accuracy: 0.8472 - val_loss: 0.4181
# Epoch 44/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8477 - loss: 0.4158 - val_accuracy: 0.8470 - val_loss: 0.4180
# Epoch 45/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8479 - loss: 0.4157 - val_accuracy: 0.8470 - val_loss: 0.4180
# Epoch 46/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8478 - loss: 0.4157 - val_accuracy: 0.8469 - val_loss: 0.4180
# Epoch 47/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8478 - loss: 0.4157 - val_accuracy: 0.8470 - val_loss: 0.4180
# Epoch 48/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8478 - loss: 0.4158 - val_accuracy: 0.8472 - val_loss: 0.4180
# Epoch 49/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8479 - loss: 0.4157 - val_accuracy: 0.8471 - val_loss: 0.4180
# Epoch 50/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8479 - loss: 0.4157 - val_accuracy: 0.8472 - val_loss: 0.4180
# Epoch 51/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8479 - loss: 0.4157 - val_accuracy: 0.8470 - val_loss: 0.4180
# Epoch 52/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8478 - loss: 0.4157 - val_accuracy: 0.8470 - val_loss: 0.4180
# Epoch 53/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8479 - loss: 0.4157 - val_accuracy: 0.8470 - val_loss: 0.4179
# Epoch 54/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.8477 - loss: 0.4157 - val_accuracy: 0.8468 - val_loss: 0.4179
# Epoch 55/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.8479 - loss: 0.4156 - val_accuracy: 0.8469 - val_loss: 0.4178
# Epoch 56/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8480 - loss: 0.4156 - val_accuracy: 0.8469 - val_loss: 0.4179
# Epoch 57/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8479 - loss: 0.4156 - val_accuracy: 0.8469 - val_loss: 0.4179
# Epoch 58/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8478 - loss: 0.4156 - val_accuracy: 0.8470 - val_loss: 0.4179
# Epoch 59/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.8478 - loss: 0.4156 - val_accuracy: 0.8472 - val_loss: 0.4179
# Epoch 60/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8476 - loss: 0.4156 - val_accuracy: 0.8471 - val_loss: 0.4178
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# === Classification Report (Macro) DNN + KCC + AE + SA ===
#               precision    recall  f1-score   support
#
#            0     0.8564    0.9856    0.9165     42741
#            1     0.0000    0.0000    0.0000       926
#            2     0.5727    0.1253    0.2057      7069
#
#     accuracy                         0.8478     50736
#    macro avg     0.4764    0.3703    0.3741     50736
# weighted avg     0.8013    0.8478    0.8007     50736
#
#
# Macro-average ROC AUC: 0.7578
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Model berhasil disimpan di: /content/drive/MyDrive/Projects/DNN untuk Prediksi status diabetes/Model/dnn+kcc+ae+sa.keras
