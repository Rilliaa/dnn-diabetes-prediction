# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/diabetes_012_health_indicators_BRFSS2015.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 4. Preprocessing
X['BMI'] = winsorize(X['BMI'], limits=[0.005, 0.005])
X['MentHlth'] = np.where(X['MentHlth'] > 30, 30, X['MentHlth'])
X['PhysHlth'] = np.where(X['PhysHlth'] > 30, 30, X['PhysHlth'])

robust_features = ['BMI', 'MentHlth', 'PhysHlth']
minmax_features = ['Age', 'Education', 'Income', 'GenHlth']

scaler_robust = RobustScaler()
scaler_minmax = MinMaxScaler()

X[robust_features] = scaler_robust.fit_transform(X[robust_features])
X[minmax_features] = scaler_minmax.fit_transform(X[minmax_features])

# 5. Split Data (Train/Test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED, stratify=y
)

# 6. SMOTE on Train Data Only
smote = SMOTE(random_state=SEED)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Simpan hasil SMOTE jika dibutuhkan
# df_train_smote = pd.DataFrame(X_train_smote, columns=X_train.columns)
# df_train_smote['Diabetes_012'] = y_train_smote
# df_train_smote.to_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/Output DNN+SMOTE.csv', index=False)

# 7. One-hot Encoding
y_train_encoded = to_categorical(y_train_smote)
y_test_encoded = to_categorical(y_test)

# 8. Split Train → Train Main & Validation
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train_smote, y_train_encoded, test_size=0.2, random_state=SEED, stratify=y_train_smote
)

# 9. Build DNN + Self-Attention Model
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimension for self-attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention Layer
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Flatten back to 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output Layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model = Model(inputs=input_layer, outputs=output_layer)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 10. Train Model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 11. Evaluate on Test Set
y_pred_prob = model.predict(X_test)
y_pred_class = np.argmax(y_pred_prob, axis=1)
y_true_class = np.argmax(y_test_encoded, axis=1)

# 12. Metrik Evaluasi
print("\n=== Classification Report (Macro) Model DNN + SMOTE + SA ===")
print(classification_report(y_true_class, y_pred_class, digits=4))
roc_auc = roc_auc_score(y_test_encoded, y_pred_prob, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc:.4f}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - accuracy: 0.5272 - loss: 0.9409 - val_accuracy: 0.5793 - val_loss: 0.8799
# Epoch 2/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.5867 - loss: 0.8739 - val_accuracy: 0.6030 - val_loss: 0.8491
# Epoch 3/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6148 - loss: 0.8312 - val_accuracy: 0.6191 - val_loss: 0.8265
# Epoch 4/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6315 - loss: 0.8041 - val_accuracy: 0.6305 - val_loss: 0.8108
# Epoch 5/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 45s 5ms/step - accuracy: 0.6431 - loss: 0.7855 - val_accuracy: 0.6376 - val_loss: 0.7975
# Epoch 6/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 77s 5ms/step - accuracy: 0.6509 - loss: 0.7724 - val_accuracy: 0.6472 - val_loss: 0.7820
# Epoch 7/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.6574 - loss: 0.7623 - val_accuracy: 0.6508 - val_loss: 0.7746
# Epoch 8/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.6615 - loss: 0.7544 - val_accuracy: 0.6530 - val_loss: 0.7703
# Epoch 9/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 77s 5ms/step - accuracy: 0.6652 - loss: 0.7471 - val_accuracy: 0.6573 - val_loss: 0.7642
# Epoch 10/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.6689 - loss: 0.7410 - val_accuracy: 0.6592 - val_loss: 0.7604
# Epoch 11/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.6722 - loss: 0.7353 - val_accuracy: 0.6639 - val_loss: 0.7531
# Epoch 12/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 78s 5ms/step - accuracy: 0.6749 - loss: 0.7301 - val_accuracy: 0.6637 - val_loss: 0.7536
# Epoch 13/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 5ms/step - accuracy: 0.6773 - loss: 0.7256 - val_accuracy: 0.6726 - val_loss: 0.7360
# Epoch 14/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 78s 5ms/step - accuracy: 0.6796 - loss: 0.7216 - val_accuracy: 0.6758 - val_loss: 0.7305
# Epoch 15/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.6821 - loss: 0.7183 - val_accuracy: 0.6764 - val_loss: 0.7286
# Epoch 16/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 5ms/step - accuracy: 0.6832 - loss: 0.7150 - val_accuracy: 0.6786 - val_loss: 0.7240
# Epoch 17/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 6ms/step - accuracy: 0.6850 - loss: 0.7124 - val_accuracy: 0.6818 - val_loss: 0.7180
# Epoch 18/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.6864 - loss: 0.7097 - val_accuracy: 0.6812 - val_loss: 0.7194
# Epoch 19/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.6877 - loss: 0.7071 - val_accuracy: 0.6815 - val_loss: 0.7179
# Epoch 20/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 82s 5ms/step - accuracy: 0.6889 - loss: 0.7046 - val_accuracy: 0.6830 - val_loss: 0.7143
# Epoch 21/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6905 - loss: 0.7024 - val_accuracy: 0.6853 - val_loss: 0.7103
# Epoch 22/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.6914 - loss: 0.7002 - val_accuracy: 0.6860 - val_loss: 0.7096
# Epoch 23/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.6931 - loss: 0.6978 - val_accuracy: 0.6885 - val_loss: 0.7059
# Epoch 24/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.6936 - loss: 0.6957 - val_accuracy: 0.6896 - val_loss: 0.7023
# Epoch 25/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.6947 - loss: 0.6940 - val_accuracy: 0.6901 - val_loss: 0.7029
# Epoch 26/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6957 - loss: 0.6920 - val_accuracy: 0.6906 - val_loss: 0.7015
# Epoch 27/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 5ms/step - accuracy: 0.6963 - loss: 0.6903 - val_accuracy: 0.6914 - val_loss: 0.7005
# Epoch 28/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6972 - loss: 0.6890 - val_accuracy: 0.6924 - val_loss: 0.7000
# Epoch 29/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6980 - loss: 0.6874 - val_accuracy: 0.6927 - val_loss: 0.6953
# Epoch 30/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.6987 - loss: 0.6863 - val_accuracy: 0.6937 - val_loss: 0.6941
# Epoch 31/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.6988 - loss: 0.6851 - val_accuracy: 0.6936 - val_loss: 0.6944
# Epoch 32/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.6997 - loss: 0.6837 - val_accuracy: 0.6935 - val_loss: 0.6955
# Epoch 33/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.7005 - loss: 0.6827 - val_accuracy: 0.6939 - val_loss: 0.6944
# Epoch 34/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.7011 - loss: 0.6812 - val_accuracy: 0.6954 - val_loss: 0.6927
# Epoch 35/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.7008 - loss: 0.6804 - val_accuracy: 0.6970 - val_loss: 0.6915
# Epoch 36/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 46s 6ms/step - accuracy: 0.7014 - loss: 0.6792 - val_accuracy: 0.6972 - val_loss: 0.6907
# Epoch 37/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.7017 - loss: 0.6783 - val_accuracy: 0.6969 - val_loss: 0.6900
# Epoch 38/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.7018 - loss: 0.6773 - val_accuracy: 0.6991 - val_loss: 0.6858
# Epoch 39/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.7029 - loss: 0.6761 - val_accuracy: 0.6986 - val_loss: 0.6875
# Epoch 40/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.7028 - loss: 0.6751 - val_accuracy: 0.6981 - val_loss: 0.6874
# Epoch 41/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.7038 - loss: 0.6741 - val_accuracy: 0.6978 - val_loss: 0.6886
# Epoch 42/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.7040 - loss: 0.6732 - val_accuracy: 0.6994 - val_loss: 0.6862
# Epoch 43/100
# 8207/8207 ━━━━━━━━━━━━━━━━━━━━ 78s 5ms/step - accuracy: 0.7045 - loss: 0.6726 - val_accuracy: 0.6995 - val_loss: 0.6859
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# === Classification Report (Macro) Model DNN + SMOTE + SA ===
#               precision    recall  f1-score   support
#
#            0     0.9382    0.6559    0.7721     42741
#            1     0.0254    0.2160    0.0454       926
#            2     0.3245    0.5957    0.4202      7069
#
#     accuracy                         0.6395     50736
#    macro avg     0.4294    0.4892    0.4126     50736
# weighted avg     0.8360    0.6395    0.7098     50736
#
#
# Macro-average ROC AUC: 0.7172
