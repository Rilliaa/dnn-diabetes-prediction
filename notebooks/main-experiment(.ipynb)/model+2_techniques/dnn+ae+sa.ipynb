# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score
from scipy.stats.mstats import winsorize
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Dropout, Lambda
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/AE/AEB1_dataset_latent.csv')
X = data.drop('Diabetes_012', axis=1)
y = data['Diabetes_012']

# 5. One-hot Encoding untuk Target
y_encoded = to_categorical(y)

# 6. Split Data (Train/Test -> Train/Val)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=SEED, stratify=y
)
X_train_main, X_val, y_train_main, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=SEED, stratify=y_train.argmax(axis=1)
)

# 7. Build DNN + Self-Attention Layer (Moved before Output Layer)
input_layer = Input(shape=(X.shape[1],))
x = Dense(64, activation='relu')(input_layer)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# Expand dimensi untuk Self-Attention
x_expanded = Lambda(lambda t: tf.expand_dims(t, axis=1))(x)

# Self-Attention sebelum output
attn_output = MultiHeadAttention(num_heads=4, key_dim=4)(x_expanded, x_expanded)
attn_output = LayerNormalization()(attn_output + x_expanded)

# Kembalikan ke bentuk 2D
attn_output_squeezed = Lambda(lambda t: tf.squeeze(t, axis=1))(attn_output)

# Output layer
output_layer = Dense(3, activation='softmax')(attn_output_squeezed)

# Final Model
model_sa = Model(inputs=input_layer, outputs=output_layer)
model_sa.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Train Model (Updated Epochs: 100)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_sa = model_sa.fit(
    X_train_main, y_train_main,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=50,
    callbacks=[early_stop],
    verbose=1
)

# 9. Evaluate
y_pred_prob_sa = model_sa.predict(X_test)
y_pred_class_sa = np.argmax(y_pred_prob_sa, axis=1)
y_true_class_sa = np.argmax(y_test, axis=1)

print("\n=== Classification Report (Macro) DNN AE + SA ===")
print(classification_report(y_true_class_sa, y_pred_class_sa, digits=4))
roc_auc_sa = roc_auc_score(y_test, y_pred_prob_sa, average='macro', multi_class='ovr')
print(f"\nMacro-average ROC AUC: {roc_auc_sa:.4f}")
# Out:
# Mounted at /content/drive
# Epoch 1/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8414 - loss: 0.4332 - val_accuracy: 0.8448 - val_loss: 0.4311
# Epoch 2/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8464 - loss: 0.4135 - val_accuracy: 0.8458 - val_loss: 0.4252
# Epoch 3/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8467 - loss: 0.4121 - val_accuracy: 0.8458 - val_loss: 0.4182
# Epoch 4/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8470 - loss: 0.4111 - val_accuracy: 0.8464 - val_loss: 0.4165
# Epoch 5/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8476 - loss: 0.4104 - val_accuracy: 0.8463 - val_loss: 0.4137
# Epoch 6/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8477 - loss: 0.4096 - val_accuracy: 0.8472 - val_loss: 0.4140
# Epoch 7/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8477 - loss: 0.4091 - val_accuracy: 0.8466 - val_loss: 0.4131
# Epoch 8/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8481 - loss: 0.4084 - val_accuracy: 0.8474 - val_loss: 0.4126
# Epoch 9/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8483 - loss: 0.4081 - val_accuracy: 0.8475 - val_loss: 0.4110
# Epoch 10/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8482 - loss: 0.4074 - val_accuracy: 0.8473 - val_loss: 0.4130
# Epoch 11/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.8481 - loss: 0.4071 - val_accuracy: 0.8476 - val_loss: 0.4118
# Epoch 12/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8481 - loss: 0.4067 - val_accuracy: 0.8476 - val_loss: 0.4104
# Epoch 13/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8479 - loss: 0.4062 - val_accuracy: 0.8475 - val_loss: 0.4100
# Epoch 14/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8483 - loss: 0.4059 - val_accuracy: 0.8471 - val_loss: 0.4100
# Epoch 15/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8482 - loss: 0.4056 - val_accuracy: 0.8474 - val_loss: 0.4090
# Epoch 16/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8482 - loss: 0.4052 - val_accuracy: 0.8476 - val_loss: 0.4089
# Epoch 17/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8485 - loss: 0.4050 - val_accuracy: 0.8476 - val_loss: 0.4076
# Epoch 18/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8481 - loss: 0.4045 - val_accuracy: 0.8472 - val_loss: 0.4086
# Epoch 19/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8483 - loss: 0.4044 - val_accuracy: 0.8476 - val_loss: 0.4079
# Epoch 20/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8484 - loss: 0.4040 - val_accuracy: 0.8474 - val_loss: 0.4076
# Epoch 21/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8485 - loss: 0.4038 - val_accuracy: 0.8472 - val_loss: 0.4062
# Epoch 22/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8480 - loss: 0.4037 - val_accuracy: 0.8473 - val_loss: 0.4060
# Epoch 23/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8484 - loss: 0.4035 - val_accuracy: 0.8470 - val_loss: 0.4048
# Epoch 24/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8486 - loss: 0.4033 - val_accuracy: 0.8477 - val_loss: 0.4063
# Epoch 25/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8487 - loss: 0.4030 - val_accuracy: 0.8473 - val_loss: 0.4058
# Epoch 26/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8484 - loss: 0.4028 - val_accuracy: 0.8474 - val_loss: 0.4048
# Epoch 27/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8486 - loss: 0.4026 - val_accuracy: 0.8474 - val_loss: 0.4069
# Epoch 28/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.8488 - loss: 0.4026 - val_accuracy: 0.8471 - val_loss: 0.4044
# Epoch 29/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8486 - loss: 0.4023 - val_accuracy: 0.8472 - val_loss: 0.4064
# Epoch 30/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8487 - loss: 0.4023 - val_accuracy: 0.8479 - val_loss: 0.4050
# Epoch 31/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.8488 - loss: 0.4021 - val_accuracy: 0.8476 - val_loss: 0.4060
# Epoch 32/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8484 - loss: 0.4020 - val_accuracy: 0.8476 - val_loss: 0.4076
# Epoch 33/100
# 3248/3248 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8487 - loss: 0.4018 - val_accuracy: 0.8477 - val_loss: 0.4062
# 1586/1586 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# === Classification Report (Macro) DNN AE + SA ===
#               precision    recall  f1-score   support
#
#            0     0.8565    0.9858    0.9166     42741
#            1     0.0000    0.0000    0.0000       926
#            2     0.5724    0.1248    0.2049      7069
#
#     accuracy                         0.8479     50736
#    macro avg     0.4763    0.3702    0.3738     50736
# weighted avg     0.8013    0.8479    0.8007     50736
#
#
# Macro-average ROC AUC: 0.7764
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
