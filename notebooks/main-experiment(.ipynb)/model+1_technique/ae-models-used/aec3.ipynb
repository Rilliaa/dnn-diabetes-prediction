# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from scipy.stats.mstats import winsorize
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/diabetes_012_health_indicators_BRFSS2015.csv')
X = data.drop('Diabetes_012', axis=1)

# 4. Preprocessing
X['BMI'] = winsorize(X['BMI'], limits=[0.005, 0.005])
X['MentHlth'] = np.where(X['MentHlth'] > 30, 30, X['MentHlth'])
X['PhysHlth'] = np.where(X['PhysHlth'] > 30, 30, X['PhysHlth'])

robust_features = ['BMI', 'MentHlth', 'PhysHlth']
minmax_features = ['Age', 'Education', 'Income', 'GenHlth']

scaler_robust = RobustScaler()
scaler_minmax = MinMaxScaler()

X[robust_features] = scaler_robust.fit_transform(X[robust_features])
X[minmax_features] = scaler_minmax.fit_transform(X[minmax_features])

# 5. Split Data
X_train_ae, X_test_ae = train_test_split(X, test_size=0.2, random_state=SEED)

# 6. Build Autoencoder AE C3 with LeakyReLU
input_dim = X.shape[1]
input_layer = Input(shape=(input_dim,))

x = Dense(14)(input_layer)
x = LeakyReLU(alpha=0.1)(x)
x = Dense(8)(x)
x = LeakyReLU(alpha=0.1)(x)

latent = Dense(6)(x)
latent = LeakyReLU(alpha=0.1)(latent)

x = Dense(8)(latent)
x = LeakyReLU(alpha=0.1)(x)
x = Dense(14)(x)
x = LeakyReLU(alpha=0.1)(x)

output_layer = Dense(input_dim, activation='linear')(x)

autoencoder = Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer='adam', loss='mse')

# 7. Train Autoencoder
history = autoencoder.fit(
    X_train_ae, X_train_ae,
    validation_data=(X_test_ae, X_test_ae),
    epochs=100,
    batch_size=50,
    verbose=1,
    callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)

# 8. Simpan Model
save_dir = '/content/drive/MyDrive/Colab Notebooks/Skripsi/Model/Model Autoencoders'
os.makedirs(save_dir, exist_ok=True)
# autoencoder.save(f'{save_dir}/aec3_model_leakyrelu.h5')

# 9. Ekstrak Encoder
encoder = Model(inputs=input_layer, outputs=latent)

# 10. Transformasi seluruh data ke bentuk laten
X_latent = encoder.predict(X)

# 11. Buat DataFrame hasil reduksi dimensi
latent_df = pd.DataFrame(X_latent, columns=[f'Latent_{i+1}' for i in range(X_latent.shape[1])])

# 12. Tambahkan label
latent_df['Diabetes_012'] = data['Diabetes_012']

# 13. Simpan ke direktori
output_path = '/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/AE'
os.makedirs(output_path, exist_ok=True)
latent_df.to_csv(f'{output_path}/AEC3_dataset_latent.csv', index=False)

print("✅ Dataset latent berhasil disimpan dengan LeakyReLU.")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.3090 - val_loss: 0.0772
# Epoch 2/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0691 - val_loss: 0.0573
# Epoch 3/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0568 - val_loss: 0.0539
# Epoch 4/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0537 - val_loss: 0.0531
# Epoch 5/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0531 - val_loss: 0.0528
# Epoch 6/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0529 - val_loss: 0.0527
# Epoch 7/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0528 - val_loss: 0.0525
# Epoch 8/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0526 - val_loss: 0.0525
# Epoch 9/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0526 - val_loss: 0.0524
# Epoch 10/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0525 - val_loss: 0.0523
# Epoch 11/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0524 - val_loss: 0.0523
# Epoch 12/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0523 - val_loss: 0.0521
# Epoch 13/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0522 - val_loss: 0.0520
# Epoch 14/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.0520 - val_loss: 0.0519
# Epoch 15/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0518 - val_loss: 0.0517
# Epoch 16/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0517 - val_loss: 0.0515
# Epoch 17/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0515 - val_loss: 0.0513
# Epoch 18/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0513 - val_loss: 0.0510
# Epoch 19/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0509 - val_loss: 0.0505
# Epoch 20/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0505 - val_loss: 0.0501
# Epoch 21/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0500 - val_loss: 0.0498
# Epoch 22/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0496 - val_loss: 0.0493
# Epoch 23/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0485 - val_loss: 0.0458
# Epoch 24/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0453 - val_loss: 0.0445
# Epoch 25/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0444 - val_loss: 0.0441
# Epoch 26/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0440 - val_loss: 0.0438
# Epoch 27/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0438 - val_loss: 0.0436
# Epoch 28/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0437 - val_loss: 0.0435
# Epoch 29/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0436 - val_loss: 0.0435
# Epoch 30/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0435 - val_loss: 0.0434
# Epoch 31/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0435 - val_loss: 0.0434
# Epoch 32/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0434 - val_loss: 0.0434
# Epoch 33/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0434 - val_loss: 0.0433
# Epoch 34/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.0434 - val_loss: 0.0433
# Epoch 35/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0433 - val_loss: 0.0432
# Epoch 36/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0433 - val_loss: 0.0432
# Epoch 37/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0433 - val_loss: 0.0432
# Epoch 38/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0432 - val_loss: 0.0432
# Epoch 39/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0432 - val_loss: 0.0432
# Epoch 40/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0432 - val_loss: 0.0431
# Epoch 41/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0432 - val_loss: 0.0431
# Epoch 42/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0432 - val_loss: 0.0431
# Epoch 43/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 44/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 45/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 46/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.0431 - val_loss: 0.0430
# Epoch 47/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.0430 - val_loss: 0.0429
# Epoch 48/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0430 - val_loss: 0.0429
# Epoch 49/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0430 - val_loss: 0.0429
# Epoch 50/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0430 - val_loss: 0.0429
# Epoch 51/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0430 - val_loss: 0.0428
# Epoch 52/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0429 - val_loss: 0.0428
# Epoch 53/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0429 - val_loss: 0.0428
# Epoch 54/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0429 - val_loss: 0.0428
# Epoch 55/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0429 - val_loss: 0.0427
# Epoch 56/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 57/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 58/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 59/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 60/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 61/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0427 - val_loss: 0.0427
# Epoch 62/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0427 - val_loss: 0.0427
# Epoch 63/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0427 - val_loss: 0.0426
# Epoch 64/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0427 - val_loss: 0.0426
# Epoch 65/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0427 - val_loss: 0.0426
# Epoch 66/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0426 - val_loss: 0.0426
# Epoch 67/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0426 - val_loss: 0.0426
# Epoch 68/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0426 - val_loss: 0.0425
# Epoch 69/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0426 - val_loss: 0.0425
# Epoch 70/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0426 - val_loss: 0.0425
# Epoch 71/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0425 - val_loss: 0.0425
# Epoch 72/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0425 - val_loss: 0.0425
# Epoch 73/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0425 - val_loss: 0.0424
# Epoch 74/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0425 - val_loss: 0.0424
# Epoch 75/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0424 - val_loss: 0.0424
# Epoch 76/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0424 - val_loss: 0.0424
# Epoch 77/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0424 - val_loss: 0.0424
# Epoch 78/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0424 - val_loss: 0.0424
# Epoch 79/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0423 - val_loss: 0.0424
# Epoch 80/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0423 - val_loss: 0.0423
# Epoch 81/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0423 - val_loss: 0.0423
# Epoch 82/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0422 - val_loss: 0.0422
# Epoch 83/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0422 - val_loss: 0.0421
# Epoch 84/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0422 - val_loss: 0.0421
# Epoch 85/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0421 - val_loss: 0.0420
# Epoch 86/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0419 - val_loss: 0.0417
# Epoch 87/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0417 - val_loss: 0.0416
# Epoch 88/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0415 - val_loss: 0.0413
# Epoch 89/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0411 - val_loss: 0.0408
# Epoch 90/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0407 - val_loss: 0.0403
# Epoch 91/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.0400 - val_loss: 0.0393
# Epoch 92/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0391 - val_loss: 0.0388
# Epoch 93/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0388 - val_loss: 0.0386
# Epoch 94/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0386 - val_loss: 0.0385
# Epoch 95/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0385 - val_loss: 0.0384
# Epoch 96/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0384 - val_loss: 0.0383
# Epoch 97/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.0384 - val_loss: 0.0383
# Epoch 98/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0383 - val_loss: 0.0382
# Epoch 99/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0382 - val_loss: 0.0382
# Epoch 100/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0382 - val_loss: 0.0381
# 7928/7928 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# ✅ Dataset latent berhasil disimpan dengan LeakyReLU.
