# %%
# 0. Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1. Import Libraries
import numpy as np
import pandas as pd
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from scipy.stats.mstats import winsorize
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# 2. Set Seed untuk Konsistensi
SEED = 44
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 3. Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/diabetes_012_health_indicators_BRFSS2015.csv')
X = data.drop('Diabetes_012', axis=1)

# 4. Preprocessing (Sesuai Model Default)
X['BMI'] = winsorize(X['BMI'], limits=[0.005, 0.005])
X['MentHlth'] = np.where(X['MentHlth'] > 30, 30, X['MentHlth'])
X['PhysHlth'] = np.where(X['PhysHlth'] > 30, 30, X['PhysHlth'])

robust_features = ['BMI', 'MentHlth', 'PhysHlth']
minmax_features = ['Age', 'Education', 'Income', 'GenHlth']

scaler_robust = RobustScaler()
scaler_minmax = MinMaxScaler()

X[robust_features] = scaler_robust.fit_transform(X[robust_features])
X[minmax_features] = scaler_minmax.fit_transform(X[minmax_features])

# 5. Split Data untuk AE (tidak butuh label y)
X_train_ae, X_test_ae = train_test_split(X, test_size=0.2, random_state=SEED)

# 6. Build Autoencoder AE A3 dengan LeakyReLU
input_dim = X.shape[1]
input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(18)(input_layer)
x = LeakyReLU(alpha=0.1)(x)
x = Dense(12)(x)
x = LeakyReLU(alpha=0.1)(x)

# Latent space
latent = Dense(10)(x)
latent = LeakyReLU(alpha=0.1)(latent)

# Decoder
x = Dense(12)(latent)
x = LeakyReLU(alpha=0.1)(x)
x = Dense(18)(x)
x = LeakyReLU(alpha=0.1)(x)

# Output layer
output_layer = Dense(input_dim, activation='linear')(x)

# Model setup
autoencoder = Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer='adam', loss='mse')

# 7. Train Autoencoder
history = autoencoder.fit(
    X_train_ae, X_train_ae,
    validation_data=(X_test_ae, X_test_ae),
    epochs=100,
    batch_size=50,
    verbose=1,
    callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)

# 8. Simpan Model
save_dir = '/content/drive/MyDrive/Colab Notebooks/Skripsi/Model/Model Autoencoders'
os.makedirs(save_dir, exist_ok=True)
# autoencoder.save(f'{save_dir}/aes3_model_leakyrelu.h5')

# 9. Ekstrak Encoder dari Autoencoder
encoder = Model(inputs=input_layer, outputs=latent)

# 10. Transformasi seluruh data X menjadi bentuk laten
X_latent = encoder.predict(X)

# 11. Buat DataFrame hasil reduksi dimensi
latent_df = pd.DataFrame(X_latent, columns=[f'Latent_{i+1}' for i in range(X_latent.shape[1])])

# 12. Tambahkan label (opsional)
latent_df['Diabetes_012'] = data['Diabetes_012']

# 13. Simpan ke direktori yang ditentukan
output_path = '/content/drive/MyDrive/Colab Notebooks/Skripsi/Dataset/V2 Hasil Eksperimen/AE'
os.makedirs(output_path, exist_ok=True)
latent_df.to_csv(f'{output_path}/AEA3_dataset_latent.csv', index=False)

print("✅ Dataset latent berhasil disimpan.")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.2496 - val_loss: 0.0560
# Epoch 2/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0530 - val_loss: 0.0439
# Epoch 3/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0423 - val_loss: 0.0354
# Epoch 4/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0354 - val_loss: 0.0351
# Epoch 5/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0353 - val_loss: 0.0351
# Epoch 6/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0352 - val_loss: 0.0351
# Epoch 7/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0352 - val_loss: 0.0351
# Epoch 8/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0352 - val_loss: 0.0351
# Epoch 9/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0351 - val_loss: 0.0351
# Epoch 10/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0351 - val_loss: 0.0350
# Epoch 11/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0351 - val_loss: 0.0350
# Epoch 12/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0351 - val_loss: 0.0350
# Epoch 13/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0344 - val_loss: 0.0309
# Epoch 14/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0305 - val_loss: 0.0298
# Epoch 15/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0296 - val_loss: 0.0291
# Epoch 16/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0288 - val_loss: 0.0282
# Epoch 17/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0280 - val_loss: 0.0276
# Epoch 18/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0276 - val_loss: 0.0275
# Epoch 19/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0275 - val_loss: 0.0274
# Epoch 20/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0274 - val_loss: 0.0274
# Epoch 21/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0273 - val_loss: 0.0273
# Epoch 22/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0270 - val_loss: 0.0251
# Epoch 23/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0248 - val_loss: 0.0245
# Epoch 24/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0243 - val_loss: 0.0243
# Epoch 25/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0241 - val_loss: 0.0242
# Epoch 26/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0241 - val_loss: 0.0241
# Epoch 27/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 0.0240 - val_loss: 0.0241
# Epoch 28/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 29/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 30/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0239 - val_loss: 0.0240
# Epoch 31/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 32/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 33/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 34/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 35/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 36/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 37/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 38/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 39/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 40/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0237 - val_loss: 0.0237
# Epoch 41/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0237 - val_loss: 0.0237
# Epoch 42/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0236 - val_loss: 0.0236
# Epoch 43/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0235 - val_loss: 0.0234
# Epoch 44/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0234 - val_loss: 0.0234
# Epoch 45/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.0233 - val_loss: 0.0233
# Epoch 46/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0232 - val_loss: 0.0233
# Epoch 47/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0232 - val_loss: 0.0232
# Epoch 48/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0232 - val_loss: 0.0231
# Epoch 49/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0230 - val_loss: 0.0231
# Epoch 50/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 51/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 52/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 53/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0230 - val_loss: 0.0229
# Epoch 54/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 55/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 56/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 57/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 58/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 59/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 60/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 61/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 62/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 63/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 64/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 65/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 66/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0227 - val_loss: 0.0223
# Epoch 67/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 68/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 69/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 70/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 71/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 72/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 73/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 74/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 75/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 76/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 77/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 78/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 79/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 80/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 81/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 82/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 83/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 84/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 85/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 86/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 87/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 88/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0220 - val_loss: 0.0218
# Epoch 89/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 90/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 91/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 92/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0220 - val_loss: 0.0218
# Epoch 93/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 94/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 95/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 96/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 97/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 98/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 99/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 100/100
# 4059/4059 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0219 - val_loss: 0.0218
# 7928/7928 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# ✅ Dataset latent berhasil disimpan.
